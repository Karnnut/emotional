# %%
import numpy as np
import pandas as pd 
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objs as go
from plotly import tools
from plotly.subplots import make_subplots
import plotly.offline as py
from sklearn.cluster import DBSCAN
import plotly.express as px
import os
import math

# %%
def main():
    directory_aggressive = '/Users/pinto/Desktop/Arbeit/emotional/Aggressive'
    aggressive_time = []
    aggressive_speed_out_list = []
    aggressive_speed_cross_list = []

    for filename in os.scandir(directory_aggressive):
        df = pd.read_csv(filename.path)
        aggressive_time.append(time(df))

        average_speed_out = sum_speed(df)
        average_speed_out1 = average_speed_out[0] / average_speed_out[1]
        aggressive_speed_out_list.append(average_speed_out1)
        
        average_speed_cross = sum_speed_cross(df)
        average_speed_cross1 = average_speed_cross[0] / average_speed_cross[1]
        aggressive_speed_cross_list.append(average_speed_cross1)


    
    result_aggressive_time = find_max_min_median(aggressive_time)
    result_aggressive_out = find_max_min_median(aggressive_speed_out_list)
    result_aggressive_cross = find_max_min_median(aggressive_speed_cross_list)
    print("aggressive_time = ", result_aggressive_time)
    print("aggressive_out = ", result_aggressive_out)
    print("aggressive_cross = ", result_aggressive_cross)
    # print(aggressive_speed_cross_list)
    # print(aggressive_speed_out_list)
    # print(aggressive_time)

    
    print()

    directory_cautious= '/Users/pinto/Desktop/Arbeit/emotional/Cautious'
    cautious_time = []
    cautious_speed_out_list = []
    cautious_speed_cross_list = []
    for filename in os.scandir(directory_cautious):
        df = pd.read_csv(filename.path)
        cautious_time.append(time(df))

        average_speed_out = sum_speed(df)
        average_speed_out1 = average_speed_out[0] / average_speed_out[1]
        cautious_speed_out_list.append(average_speed_out1)

        average_speed_cross = sum_speed_cross(df)
        average_speed_cross1 = average_speed_cross[0] / average_speed_cross[1]
        cautious_speed_cross_list.append(average_speed_cross1)

    result_cautious_time = find_max_min_median(cautious_time)
    result_cautious_out = find_max_min_median(cautious_speed_out_list)
    result_cautious_cross = find_max_min_median(cautious_speed_cross_list)
    print("cautious_time", result_cautious_time)
    print("cautious_out", result_cautious_out)
    print("cautious_cross = ", result_cautious_cross)

    # print(cautious_speed_cross_list)
    # print(cautious_speed_out_list)
    # print(cautious_time)
    print()

    directory_calmly= '/Users/pinto/Desktop/Arbeit/emotional/Calmly'
    calmly_time = []
    calmly_speed_out_list = []
    calmly_speed_cross_list = []
    for filename in os.scandir(directory_calmly):
        df = pd.read_csv(filename.path)
        calmly_time.append(time(df))

        average_speed_out = sum_speed(df)
        average_speed_out1 = average_speed_out[0] / average_speed_out[1]
        calmly_speed_out_list.append(average_speed_out1)

        average_speed_cross = sum_speed_cross(df)
        average_speed_cross1 = average_speed_cross[0] / average_speed_cross[1]
        calmly_speed_cross_list.append(average_speed_cross1)

    result_calmly_time = find_max_min_median(calmly_time)
    result_calmly_out = find_max_min_median(calmly_speed_out_list)
    result_calmly_cross = find_max_min_median(calmly_speed_cross_list)
    print("calmly_time = ",result_calmly_time)
    print("calmly_out = ",result_calmly_out)
    print("calmly_cross = ",result_calmly_cross)
        
    # print(calmly_speed_cross_list)
    # print(calmly_speed_out_list)
    # print(calmly_time)
    print()

    average_aggressive = find_average(aggressive_time)
    average_cautious = find_average(cautious_time)
    average_calmly = find_average(calmly_time)

    average_speed_out_aggressive = find_average(aggressive_speed_out_list)
    average_speed_out_cautious = find_average(cautious_speed_out_list)
    average_speed_out_calmly = find_average(calmly_speed_out_list)


    average_speed_cross_aggressive = find_average(aggressive_speed_cross_list)
    average_speed_cross_cautious = find_average(cautious_speed_cross_list)
    average_speed_cross_calmly =  find_average(calmly_speed_cross_list)

    print("Average aggressive time:",average_aggressive)
    print("Average cautious time:",average_cautious)
    print("Average calmly time:",average_calmly)

    print("Avera Speed out Aggressive", average_speed_out_aggressive)
    print("Avera Speed out Cautious", average_speed_out_cautious)
    print("Average Speed out Calmly", average_speed_out_calmly)


    print("Average Speed cross Aggressive", average_speed_cross_aggressive)
    print("Average Speed cross Cautious", average_speed_cross_cautious)
    print("Average Speed cross Calmly", average_speed_cross_calmly)

    print()

    
    X = np.array([
        aggressive_speed_out_list + cautious_speed_out_list + calmly_speed_out_list,
        aggressive_speed_cross_list + cautious_speed_cross_list + calmly_speed_cross_list,
        aggressive_time + cautious_time + calmly_time
    ]).T
    print("ALL point",X)
    # Choose the number of clusters (k)
    k = 3  # Choose the number of clusters
    n_init = 10  # Set the number of times the algorithm will be run with different centroid seeds
    kmeans = KMeans(n_clusters=k, n_init=n_init)
    
    # Fit the model to your data
    kmeans.fit(X)
    
    # Get cluster labels for each data point
    cluster_labels = kmeans.labels_
    
    # Create a 3D scatter plot
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    # Define cluster names
    cluster_names = [f'Cluster {i + 1}' for i in range(k)]
    
    colors = ['r', 'g', 'b']

    all_point = []
    
    for i in range(k):
        array = []
        cluster_x = X[cluster_labels == i, 0]  # Speed Out
        array.append(cluster_x)
        cluster_y = X[cluster_labels == i, 1]  # Speed Cross
        array.append(cluster_y)
        cluster_z = X[cluster_labels == i, 2]  # Time
        array.append(cluster_z)
        all_point.append(array)
    
        ax.scatter(cluster_x, cluster_y, cluster_z, label=cluster_names[i], c=colors[i], marker='o', s=50)

    
    # ---------------------- 3D Graph -------------------
    
    df = pd.DataFrame({
    'Speed Out': aggressive_speed_out_list + cautious_speed_out_list + calmly_speed_out_list,
    'Speed Cross': aggressive_speed_cross_list + cautious_speed_cross_list + calmly_speed_cross_list,
    'Time': aggressive_time + cautious_time + calmly_time,
    'Driving Style': ['Aggressive'] * len(aggressive_speed_cross_list) +
                     ['Cautious'] * len(cautious_speed_cross_list) +
                     ['Calmly'] * len(calmly_speed_cross_list)
    })
    
    # Create a 3D scatter plot with Plotly
    fig = px.scatter_3d(df, x='Speed Out', y='Speed Cross', z='Time', color='Driving Style', opacity=0.7, size_max=10)
    fig.update_layout(scene=dict(xaxis_title='Speed Out', yaxis_title='Speed Cross', zaxis_title='Time'))
    
    fig.show()

    # ---------------------- Create next k mean -------------------
    

    kmeans.fit(df[['Speed Out', 'Speed Cross', 'Time']])

    # Get cluster labels for each data point
    df['Cluster'] = kmeans.labels_

    # Visualize the clusters
    fig = px.scatter_3d(df, x='Speed Out', y='Speed Cross', z='Time', color='Cluster', opacity=0.7, size_max=10)
    fig.update_layout(scene=dict(xaxis_title='Speed Out', yaxis_title='Speed Cross', zaxis_title='Time'))
    fig.show()

    centroids = kmeans.cluster_centers_

    # Print the centroids
    print("Centroids of the clusters:")
    print(centroids)
    


    #------------------------ Centriod Point  ------------------------

    centroids = kmeans.cluster_centers_

    # Extract the coordinates of the centroids
    centroid_x = centroids[:, 0]  # Speed Out
    centroid_y = centroids[:, 1]  # Speed Cross
    centroid_z = centroids[:, 2]  # Time
    
    # Plot the data points and centroids
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    # Scatter plot for data points
    # (You may need to replace 'X' with your data array)
    ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=cluster_labels, cmap='viridis', s=50, label='Data Points')
    
    # Scatter plot for centroids
    ax.scatter(centroid_x, centroid_y, centroid_z, c='red', marker='X', s=100, label='Centroids')
    
    ax.set_xlabel('Speed Out')
    ax.set_ylabel('Speed Cross')
    ax.set_zlabel('Time')
    ax.set_title('K-Means Clustering with Centroids')
    ax.legend()
    plt.show()

    #------------ adjust data near centriod ---------------------------------

    distances = find_distance(X,centroids)
    print("Distance",distances)

    distances = np.linalg.norm(X[:, np.newaxis, :] - centroids, axis=2)
    print("Distance", distances)

    list_1 = []
    list_2 = []
    list_3 = []

    for j in range(len(distances)):
        array = distances[j]
        min_index = np.argmin(array)
        re = X[j]
        if (min_index == 0):
            list_1.append(re)
        elif (min_index == 1):
            list_2.append(re)
        else:
            list_3.append(re)
        
    print("Array1:",list_1)
    print()
    print("Array2:",list_2)
    print()
    print("Array3:",list_3)

    #-------------------- Show new graph -------------------------------------

    dbscan = DBSCAN(eps=0.5, min_samples=5)  # You can adjust eps and min_samples based on your data
    cluster_indices = dbscan.fit_predict(X)

    # Visualize data points and cluster labels
    visualize_clusters(X, cluster_indices)

    

    #---------------------------------------------------------------- Start a Speed Checker --------------------------------
def visualize_clusters(X, cluster_indices):
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection='3d')

    # Scatter plot for data points colored by cluster labels
    ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=cluster_indices, cmap='viridis', s=50)

    ax.set_xlabel('Speed Out')
    ax.set_ylabel('Speed Cross')
    ax.set_zlabel('Time')
    ax.set_title('DBSCAN Clustering')
    plt.show()



def find_distance(X, centroids):
    result = []
    
    for i in range(len(X)):
        re = []
        x2 = X[i][0]
        y2 = X[i][1]
        z2 = X[i][2]
        for j in range(len(centroids)):
            x = centroids[j][0]
            y = centroids[j][1]
            z = centroids[j][2]
            dist = math.sqrt(((x2 - x) ** 2) + ((y2 - y) ** 2) + ((z2 - z) ** 2))
            re.append(dist)
        result.append(re)
    return result
        
    

def find_average(list_a):
    count = len(list_a)
    sum = 0
    for i in list_a:
        sum += i
    return sum / count


def time(df):
    if not df.empty:  # Check if the DataFrame is not empty
        last_row = df.iloc[-1]
        final_time = last_row["Time"]
        return final_time
    else:
        return None


def sum_speed(df):
   sum_speed = 0
   count = 0

   for i in range(0, len(df["Speed"])):
      passed_roundabout = df["Circus entry"]
      speed = df["Speed"]
      if (passed_roundabout[i] == 1) or (passed_roundabout[i] == 2) or (passed_roundabout[i] == 3) or (passed_roundabout[i] == 4) or (passed_roundabout[i] == 5) or (passed_roundabout[i] == 6 ) or (passed_roundabout[i] == 7) or (passed_roundabout[i] == 8) or (passed_roundabout[i] == 9) or (passed_roundabout[i] == 10):
         sum_speed += speed[i]
         count += 1
   
   return sum_speed, count


def sum_speed_cross(df):
   sum_speed = 0
   count = 0

   for i in range(0, len(df["Speed"])):
      passed_cross = df["Crosswalk entry"]
      speed = df["Speed"]
      if (passed_cross[i] == 1) or (passed_cross[i] == 2) or (passed_cross[i] == 3) or (passed_cross[i] == 4) or (passed_cross[i] == 5) or (passed_cross[i] == 6):
         sum_speed += speed[i]
         count += 1
   
   return sum_speed, count

def calculate_distance(point1, point2):
    return np.sqrt(np.sum((point1 - point2) ** 2))

def find_max_min_median(list1):
  # Sort the list in ascending order.
  list1.sort()

  # Find the max and min of the list.
  max_value = list1[-1]
  min_value = list1[0]

  # Find the median of the list.
  if len(list1) % 2 == 0:
    median = (list1[len(list1) // 2] + list1[len(list1) // 2 - 1]) / 2
  else:
    median = list1[len(list1) // 2]

  return min_value, median , max_value



if __name__ == '__main__':
    main()
# Out:
# aggressive_time =  (125, 161.5, 238)
# aggressive_out =  (15.363636363636363, 29.241176470588236, 43.111111111111114)
# aggressive_cross =  (30.53846153846154, 51.5, 58.57142857142857)
#
# cautious_time (190, 229, 381)
# cautious_out (9.8, 15.25, 16.310344827586206)
# cautious_cross =  (7.5576923076923075, 13.76923076923077, 16.37037037037037)
#
# calmly_time =  (209, 302.0, 379)
# calmly_out =  (9.46, 13.573423423423424, 15.78125)
# calmly_cross =  (6.616666666666666, 11.632352941176471, 21.894736842105264)
#
# Average aggressive time: 171.7
# Average cautious time: 244.44444444444446
# Average calmly time: 291.25
# Avera Speed out Aggressive 29.84288090993973
# Avera Speed out Cautious 14.493775205189126
# Average Speed out Calmly 13.459113466860444
# Average Speed cross Aggressive 49.114163614163616
# Average Speed cross Cautious 13.196027983467596
# Average Speed cross Calmly 12.652989032837837
#
# ALL point [[ 15.36363636  30.53846154 125.        ]
#  [ 16.55555556  42.88888889 145.        ]
#  [ 26.11111111  44.         146.        ]
#  [ 28.52941176  47.125      153.        ]
#  [ 28.88235294  51.         156.        ]
#  [ 29.6         52.         167.        ]
#  [ 32.64705882  53.875      182.        ]
#  [ 34.92857143  54.14285714 202.        ]
#  [ 42.7         57.         203.        ]
#  [ 43.11111111  58.57142857 238.        ]
#  [  9.8          7.55769231 190.        ]
#  [ 13.74285714  11.57575758 194.        ]
#  [ 14.16129032  11.88571429 195.        ]
#  [ 14.48148148  13.06666667 203.        ]
#  [ 15.25        13.76923077 229.        ]
#  [ 15.35714286  13.92857143 242.        ]
#  [ 15.56666667  14.39285714 251.        ]
#  [ 15.77419355  16.2173913  315.        ]
#  [ 16.31034483  16.37037037 381.        ]
#  [  9.46         6.61666667 209.        ]
#  [ 11.38461538   9.15789474 215.        ]
#  [ 13.36363636  10.2972973  271.        ]
#  [ 13.51351351  11.17647059 300.        ]
#  [ 13.63333333  12.08823529 304.        ]
#  [ 14.90322581  14.20689655 307.        ]
#  [ 15.63333333  15.78571429 345.        ]
#  [ 15.78125     21.89473684 379.        ]]
# Centroids of the clusters:
# [[ 15.97080012  15.52907068 221.54545455]
#  [ 15.07845634  15.39140218 333.        ]
#  [ 28.36863311  48.0633564  164.33333333]]
# Distance [[97.70708907363887, 208.55098833368606, 44.98180733664487], [81.29027126949208, 190.00603568726225, 23.240088060717067], [81.36667269812322, 189.49715391206016, 18.913444474559288], [76.5147097951536, 183.2701542333552, 11.37324962126141], [75.6379642430091, 181.07324429740856, 8.850549596632229], [67.01559808422256, 170.60792673534417, 4.911673685094738], [57.553026637662924, 156.81403985211344, 19.083795195684427], [47.24877132328884, 138.04601526710377, 38.713962569677484], [52.70884166222707, 139.26315049977535, 42.194345438043534], [53.47890350277117, 108.0525076669144, 75.85867133180069], [33.117025073530066, 143.3116502996815, 51.422570303663264], [27.91674193932531, 139.05877523165938, 49.248038554483415], [26.855344505891832, 138.04756803757056, 49.50873480738621], [18.76740226611476, 130.02215493588068, 53.96973581108944], [7.693298203613855, 104.01279184457658, 74.36372344765631], [20.5262418097949, 91.0121834699826, 85.82886189695184], [29.479222394395947, 82.00753283394167, 93.85469607816549], [93.45728706497896, 18.032368349877167, 154.5096432102975], [159.45712634403435, 48.02578399127148, 219.30410877137285], [16.709574896232542, 124.43698419234889, 63.80027904930588], [10.220956340017604, 118.22225287985158, 66.09994641576269], [49.798803416058, 62.23255186849365, 114.14553396882968], [78.61360624907337, 33.30487493352119, 141.37454285447103], [82.55940385705276, 29.223266277935714, 144.97626073128362], [85.47144083363663, 26.027557690158325, 147.24589924631815], [123.45527345222223, 12.019291598086628, 183.96868887146363], [157.58328439041188, 46.46275154037716, 216.62182863396635]]
# Distance [[ 97.70708907 208.55098833  44.98180734]
#  [ 81.29027127 190.00603569  23.24008806]
#  [ 81.3666727  189.49715391  18.91344447]
#  [ 76.5147098  183.27015423  11.37324962]
#  [ 75.63796424 181.0732443    8.8505496 ]
#  [ 67.01559808 170.60792674   4.91167369]
#  [ 57.55302664 156.81403985  19.0837952 ]
#  [ 47.24877132 138.04601527  38.71396257]
#  [ 52.70884166 139.2631505   42.19434544]
#  [ 53.4789035  108.05250767  75.85867133]
#  [ 33.11702507 143.3116503   51.4225703 ]
#  [ 27.91674194 139.05877523  49.24803855]
#  [ 26.85534451 138.04756804  49.50873481]
#  [ 18.76740227 130.02215494  53.96973581]
#  [  7.6932982  104.01279184  74.36372345]
#  [ 20.52624181  91.01218347  85.8288619 ]
#  [ 29.47922239  82.00753283  93.85469608]
#  [ 93.45728706  18.03236835 154.50964321]
#  [159.45712634  48.02578399 219.30410877]
#  [ 16.7095749  124.43698419  63.80027905]
#  [ 10.22095634 118.22225288  66.09994642]
#  [ 49.79880342  62.23255187 114.14553397]
#  [ 78.61360625  33.30487493 141.37454285]
#  [ 82.55940386  29.22326628 144.97626073]
#  [ 85.47144083  26.02755769 147.24589925]
#  [123.45527345  12.0192916  183.96868887]
#  [157.58328439  46.46275154 216.62182863]]
# Array1: [array([ 43.11111111,  58.57142857, 238.        ]), array([  9.8       ,   7.55769231, 190.        ]), array([ 13.74285714,  11.57575758, 194.        ]), array([ 14.16129032,  11.88571429, 195.        ]), array([ 14.48148148,  13.06666667, 203.        ]), array([ 15.25      ,  13.76923077, 229.        ]), array([ 15.35714286,  13.92857143, 242.        ]), array([ 15.56666667,  14.39285714, 251.        ]), array([  9.46      ,   6.61666667, 209.        ]), array([ 11.38461538,   9.15789474, 215.        ]), array([ 13.36363636,  10.2972973 , 271.        ])]
#
# Array2: [array([ 15.77419355,  16.2173913 , 315.        ]), array([ 16.31034483,  16.37037037, 381.        ]), array([ 13.51351351,  11.17647059, 300.        ]), array([ 13.63333333,  12.08823529, 304.        ]), array([ 14.90322581,  14.20689655, 307.        ]), array([ 15.63333333,  15.78571429, 345.        ]), array([ 15.78125   ,  21.89473684, 379.        ])]
#
# Array3: [array([ 15.36363636,  30.53846154, 125.        ]), array([ 16.55555556,  42.88888889, 145.        ]), array([ 26.11111111,  44.        , 146.        ]), array([ 28.52941176,  47.125     , 153.        ]), array([ 28.88235294,  51.        , 156.        ]), array([ 29.6,  52. , 167. ]), array([ 32.64705882,  53.875     , 182.        ]), array([ 34.92857143,  54.14285714, 202.        ]), array([ 42.7,  57. , 203. ])]
